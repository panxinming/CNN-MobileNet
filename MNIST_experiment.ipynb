# %% [markdown]
# # Mobile Net For Image Classification

# %%
from utils.model import *
import tensorflow as tf
from keras.optimizers import SGD, RMSprop, Adam, Nadam
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. MobileNet

# %% [markdown]
# ### I. $\alpha = 1$

# %%
#Load data from the Fashion MNIST dataset
fashion_mnist = tf.keras.datasets.fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# Add a channels dimension28
x_train = x_train[..., tf.newaxis].astype("float32")
x_test = x_test[..., tf.newaxis].astype("float32")

# %%
model = mobilenet(x_train.shape[1:],10, alpha = 1)
model.compile(optimizer = RMSprop(learning_rate = 0.001, rho = 0.9), loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
history = model.fit(x_train,y_train, validation_split=0.2, 
                    epochs=10, 
                    verbose = 1)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 228s 148ms/step - loss: 0.8063 - accuracy: 0.7289 - val_loss: 1.7194 - val_accuracy: 0.7513
# Epoch 2/10
# 1500/1500 [==============================] - 216s 144ms/step - loss: 0.4837 - accuracy: 0.8418 - val_loss: 0.4166 - val_accuracy: 0.8618
# Epoch 3/10
# 1500/1500 [==============================] - 215s 143ms/step - loss: 0.4341 - accuracy: 0.8675 - val_loss: 0.3474 - val_accuracy: 0.8799
# Epoch 4/10
# 1500/1500 [==============================] - 220s 146ms/step - loss: 0.3781 - accuracy: 0.8781 - val_loss: 0.6125 - val_accuracy: 0.8553
# Epoch 5/10
# 1500/1500 [==============================] - 221s 147ms/step - loss: 0.3573 - accuracy: 0.8889 - val_loss: 1.2373 - val_accuracy: 0.8689
# Epoch 6/10
# 1500/1500 [==============================] - 221s 147ms/step - loss: 0.3288 - accuracy: 0.8948 - val_loss: 2.4177 - val_accuracy: 0.8471
# Epoch 7/10
# 1500/1500 [==============================] - 221s 147ms/step - loss: 0.3158 - accuracy: 0.9024 - val_loss: 0.4065 - val_accuracy: 0.8875
# Epoch 8/10
# 1500/1500 [==============================] - 221s 147ms/step - loss: 0.2765 - accuracy: 0.9085 - val_loss: 4.0345 - val_accuracy: 0.8730
# Epoch 9/10
# 1500/1500 [==============================] - 222s 148ms/step - loss: 0.2684 - accuracy: 0.9131 - val_loss: 1.1343 - val_accuracy: 0.8914
# Epoch 10/10
# 1500/1500 [==============================] - 223s 149ms/step - loss: 0.2602 - accuracy: 0.9167 - val_loss: 0.5049 - val_accuracy: 0.9035

# %%
plt.plot(history.history["accuracy"], label = "training")
plt.plot(history.history["val_accuracy"], label = "validation")
plt.gca().set(xlabel = "epoch", ylabel = "accuracy")
plt.legend()

# %% [markdown]
# ### II. $\alpha = 0.75$

# %%
model = mobilenet(x_train.shape[1:],10, alpha = 0.75)
model.compile(optimizer = RMSprop(learning_rate = 0.001, rho = 0.9), loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
history = model.fit(x_train,y_train, validation_split=0.2, 
                    epochs=10, 
                    verbose = 1)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 55s 35ms/step - loss: 0.7860 - accuracy: 0.7268 - val_loss: 0.5363 - val_accuracy: 0.8355
# Epoch 2/10
# 1500/1500 [==============================] - 51s 34ms/step - loss: 0.5029 - accuracy: 0.8349 - val_loss: 1.3624 - val_accuracy: 0.8093
# Epoch 3/10
# 1500/1500 [==============================] - 52s 35ms/step - loss: 0.4386 - accuracy: 0.8585 - val_loss: 0.3709 - val_accuracy: 0.8689
# Epoch 4/10
# 1500/1500 [==============================] - 52s 34ms/step - loss: 0.3871 - accuracy: 0.8712 - val_loss: 0.3305 - val_accuracy: 0.8823
# Epoch 5/10
# 1500/1500 [==============================] - 49s 33ms/step - loss: 0.3735 - accuracy: 0.8822 - val_loss: 0.3541 - val_accuracy: 0.8723
# Epoch 6/10
# 1500/1500 [==============================] - 52s 35ms/step - loss: 0.3459 - accuracy: 0.8889 - val_loss: 0.3292 - val_accuracy: 0.8882
# Epoch 7/10
# 1500/1500 [==============================] - 51s 34ms/step - loss: 0.3251 - accuracy: 0.8954 - val_loss: 0.5408 - val_accuracy: 0.8782
# Epoch 8/10
# 1500/1500 [==============================] - 53s 35ms/step - loss: 0.3075 - accuracy: 0.9009 - val_loss: 0.2869 - val_accuracy: 0.9016
# Epoch 9/10
# 1500/1500 [==============================] - 52s 34ms/step - loss: 0.2996 - accuracy: 0.9062 - val_loss: 0.2839 - val_accuracy: 0.8999
# Epoch 10/10
# 1500/1500 [==============================] - 55s 37ms/step - loss: 0.2771 - accuracy: 0.9100 - val_loss: 0.3553 - val_accuracy: 0.8972

# %%
plt.plot(history.history["accuracy"], label = "training")
plt.plot(history.history["val_accuracy"], label = "validation")
plt.gca().set(xlabel = "epoch", ylabel = "accuracy")
plt.legend()

# %% [markdown]
# ### III. $\alpha = 0.5$

# %%
model = mobilenet(x_train.shape[1:],10, alpha = 0.5)
model.compile(optimizer = RMSprop(learning_rate = 0.001, rho = 0.9), loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
history = model.fit(x_train,y_train, validation_split=0.2, 
                    epochs=10, 
                    verbose = 1)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 43s 27ms/step - loss: 0.8144 - accuracy: 0.7084 - val_loss: 0.6026 - val_accuracy: 0.8049
# Epoch 2/10
# 1500/1500 [==============================] - 40s 26ms/step - loss: 0.4897 - accuracy: 0.8309 - val_loss: 0.4592 - val_accuracy: 0.8415
# Epoch 3/10
# 1500/1500 [==============================] - 40s 27ms/step - loss: 0.4607 - accuracy: 0.8543 - val_loss: 0.4148 - val_accuracy: 0.8637
# Epoch 4/10
# 1500/1500 [==============================] - 39s 26ms/step - loss: 0.4103 - accuracy: 0.8652 - val_loss: 0.3472 - val_accuracy: 0.8733
# Epoch 5/10
# 1500/1500 [==============================] - 40s 26ms/step - loss: 0.3901 - accuracy: 0.8756 - val_loss: 0.3528 - val_accuracy: 0.8724
# Epoch 6/10
# 1500/1500 [==============================] - 41s 27ms/step - loss: 0.3718 - accuracy: 0.8831 - val_loss: 0.3352 - val_accuracy: 0.8836
# Epoch 7/10
# 1500/1500 [==============================] - 39s 26ms/step - loss: 0.3369 - accuracy: 0.8890 - val_loss: 0.3714 - val_accuracy: 0.8769
# Epoch 8/10
# 1500/1500 [==============================] - 39s 26ms/step - loss: 0.3172 - accuracy: 0.8949 - val_loss: 0.4709 - val_accuracy: 0.8811
# Epoch 9/10
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.3024 - accuracy: 0.8985 - val_loss: 0.3130 - val_accuracy: 0.8857
# Epoch 10/10
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.3034 - accuracy: 0.9032 - val_loss: 0.3452 - val_accuracy: 0.8897

# %%
plt.plot(history.history["accuracy"], label = "training")
plt.plot(history.history["val_accuracy"], label = "validation")
plt.gca().set(xlabel = "epoch", ylabel = "accuracy")
plt.legend()

# %% [markdown]
# ### IV. $\alpha = 0.25$

# %%
model = mobilenet(x_train.shape[1:],10, alpha = 0.25)
model.compile(optimizer = RMSprop(learning_rate = 0.001, rho = 0.9), loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
history = model.fit(x_train,y_train, validation_split=0.2, 
                    epochs=10, 
                    verbose = 1)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 26s 15ms/step - loss: 0.9658 - accuracy: 0.6513 - val_loss: 0.6094 - val_accuracy: 0.7893
# Epoch 2/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.5322 - accuracy: 0.8117 - val_loss: 0.5041 - val_accuracy: 0.8257
# Epoch 3/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.4534 - accuracy: 0.8389 - val_loss: 0.4226 - val_accuracy: 0.8524
# Epoch 4/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.4167 - accuracy: 0.8560 - val_loss: 0.4093 - val_accuracy: 0.8528
# Epoch 5/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.3836 - accuracy: 0.8674 - val_loss: 0.5755 - val_accuracy: 0.8197
# Epoch 6/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.3590 - accuracy: 0.8750 - val_loss: 0.3494 - val_accuracy: 0.8767
# Epoch 7/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.3451 - accuracy: 0.8814 - val_loss: 0.3457 - val_accuracy: 0.8789
# Epoch 8/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.3335 - accuracy: 0.8863 - val_loss: 0.3166 - val_accuracy: 0.8893
# Epoch 9/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.3294 - accuracy: 0.8887 - val_loss: 0.3487 - val_accuracy: 0.8746
# Epoch 10/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.3127 - accuracy: 0.8917 - val_loss: 0.3088 - val_accuracy: 0.8924

# %%
plt.plot(history.history["accuracy"], label = "training")
plt.plot(history.history["val_accuracy"], label = "validation")
plt.gca().set(xlabel = "epoch", ylabel = "accuracy")
plt.legend()

# %% [markdown]
# ## 2. Standard Convolution

# %%
model = CNN(x_train.shape[1:],10)
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_28 (Conv2D)          (None, 14, 14, 32)        320
#
#  batch_normalization_41 (Bat  (None, 14, 14, 32)       128
#  chNormalization)
#
#  re_lu_41 (ReLU)             (None, 14, 14, 32)        0
#
#  conv2d_29 (Conv2D)          (None, 14, 14, 64)        18496
#
#  batch_normalization_42 (Bat  (None, 14, 14, 64)       256
#  chNormalization)
#
#  re_lu_42 (ReLU)             (None, 14, 14, 64)        0
#
#  conv2d_30 (Conv2D)          (None, 7, 7, 128)         73856
#
#  batch_normalization_43 (Bat  (None, 7, 7, 128)        512
#  chNormalization)
#
#  re_lu_43 (ReLU)             (None, 7, 7, 128)         0
#
#  conv2d_31 (Conv2D)          (None, 7, 7, 128)         147584
#
#  batch_normalization_44 (Bat  (None, 7, 7, 128)        512
#  chNormalization)
#
#  re_lu_44 (ReLU)             (None, 7, 7, 128)         0
#
#  conv2d_32 (Conv2D)          (None, 4, 4, 256)         295168
#
#  batch_normalization_45 (Bat  (None, 4, 4, 256)        1024
#  chNormalization)
#
#  re_lu_45 (ReLU)             (None, 4, 4, 256)         0
#
#  conv2d_33 (Conv2D)          (None, 4, 4, 256)         590080
#
#  batch_normalization_46 (Bat  (None, 4, 4, 256)        1024
#  chNormalization)
#
#  re_lu_46 (ReLU)             (None, 4, 4, 256)         0
#
#  conv2d_34 (Conv2D)          (None, 2, 2, 512)         1180160
#
#  batch_normalization_47 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  re_lu_47 (ReLU)             (None, 2, 2, 512)         0
#
#  conv2d_35 (Conv2D)          (None, 2, 2, 512)         2359808
#
#  batch_normalization_48 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  re_lu_48 (ReLU)             (None, 2, 2, 512)         0
#
#  conv2d_36 (Conv2D)          (None, 2, 2, 512)         2359808
#
#  batch_normalization_49 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  re_lu_49 (ReLU)             (None, 2, 2, 512)         0
#
#  conv2d_37 (Conv2D)          (None, 2, 2, 512)         2359808
#
#  batch_normalization_50 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  re_lu_50 (ReLU)             (None, 2, 2, 512)         0
#
#  conv2d_38 (Conv2D)          (None, 2, 2, 512)         2359808
#
#  batch_normalization_51 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  re_lu_51 (ReLU)             (None, 2, 2, 512)         0
#
#  conv2d_39 (Conv2D)          (None, 2, 2, 512)         2359808
#
#  batch_normalization_52 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  re_lu_52 (ReLU)             (None, 2, 2, 512)         0
#
#  conv2d_40 (Conv2D)          (None, 1, 1, 1024)        4719616
#
#  batch_normalization_53 (Bat  (None, 1, 1, 1024)       4096
#  chNormalization)
#
#  re_lu_53 (ReLU)             (None, 1, 1, 1024)        0
#
#  conv2d_41 (Conv2D)          (None, 1, 1, 1024)        9438208
#
#  batch_normalization_54 (Bat  (None, 1, 1, 1024)       4096
#  chNormalization)
#
#  re_lu_54 (ReLU)             (None, 1, 1, 1024)        0
#
#  global_average_pooling2d_2   (None, 1024)             0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 28,296,714
# Trainable params: 28,284,746
# Non-trainable params: 11,968
# _________________________________________________________________

# %%
model.compile(optimizer = RMSprop(learning_rate = 0.001, rho = 0.9), loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
history = model.fit(x_train,y_train, validation_split=0.2, 
                    epochs=10, 
                    verbose = 1)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 3388s 2s/step - loss: 1.0371 - accuracy: 0.6119 - val_loss: 1.4692 - val_accuracy: 0.6204
# Epoch 2/10
# 1500/1500 [==============================] - 3295s 2s/step - loss: 0.6295 - accuracy: 0.7981 - val_loss: 0.9327 - val_accuracy: 0.7584
# Epoch 3/10
# 1500/1500 [==============================] - 3291s 2s/step - loss: 0.4906 - accuracy: 0.8490 - val_loss: 0.3758 - val_accuracy: 0.8655
# Epoch 4/10
# 1500/1500 [==============================] - 3273s 2s/step - loss: 0.4267 - accuracy: 0.8716 - val_loss: 0.3580 - val_accuracy: 0.8854
# Epoch 5/10
# 1500/1500 [==============================] - 3289s 2s/step - loss: 0.3838 - accuracy: 0.8851 - val_loss: 0.3282 - val_accuracy: 0.8952
# Epoch 6/10
# 1500/1500 [==============================] - 3300s 2s/step - loss: 0.3544 - accuracy: 0.8929 - val_loss: 0.3000 - val_accuracy: 0.9005
# Epoch 7/10
# 1500/1500 [==============================] - 3298s 2s/step - loss: 0.3280 - accuracy: 0.9026 - val_loss: 0.3023 - val_accuracy: 0.9023
# Epoch 8/10
# 1500/1500 [==============================] - 3289s 2s/step - loss: 0.2913 - accuracy: 0.9109 - val_loss: 0.3101 - val_accuracy: 0.8944
# Epoch 9/10
# 1500/1500 [==============================] - 3293s 2s/step - loss: 0.2781 - accuracy: 0.9169 - val_loss: 0.3402 - val_accuracy: 0.8958
# Epoch 10/10
# 1500/1500 [==============================] - 3288s 2s/step - loss: 0.2598 - accuracy: 0.9210 - val_loss: 1.2206 - val_accuracy: 0.8463

# %%
plt.plot(history.history["accuracy"], label = "training")
plt.plot(history.history["val_accuracy"], label = "validation")
plt.gca().set(xlabel = "epoch", ylabel = "accuracy")
plt.legend()

# %%
model = mobilenet(x_train.shape[1:],10, alpha = 1)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_14 (Conv2D)          (None, 14, 14, 32)        320
#
#  batch_normalization_14 (Bat  (None, 14, 14, 32)       128
#  chNormalization)
#
#  re_lu_14 (ReLU)             (None, 14, 14, 32)        0
#
#  depthwise_conv2d (Depthwise  (None, 14, 14, 32)       320
#  Conv2D)
#
#  batch_normalization_15 (Bat  (None, 14, 14, 32)       128
#  chNormalization)
#
#  re_lu_15 (ReLU)             (None, 14, 14, 32)        0
#
#  conv2d_15 (Conv2D)          (None, 14, 14, 64)        2112
#
#  batch_normalization_16 (Bat  (None, 14, 14, 64)       256
#  chNormalization)
#
#  re_lu_16 (ReLU)             (None, 14, 14, 64)        0
#
#  depthwise_conv2d_1 (Depthwi  (None, 7, 7, 64)         640
#  seConv2D)
#
#  batch_normalization_17 (Bat  (None, 7, 7, 64)         256
#  chNormalization)
#
#  re_lu_17 (ReLU)             (None, 7, 7, 64)          0
#
#  conv2d_16 (Conv2D)          (None, 7, 7, 128)         8320
#
#  batch_normalization_18 (Bat  (None, 7, 7, 128)        512
#  chNormalization)
#
#  re_lu_18 (ReLU)             (None, 7, 7, 128)         0
#
#  depthwise_conv2d_2 (Depthwi  (None, 7, 7, 128)        1280
#  seConv2D)
#
#  batch_normalization_19 (Bat  (None, 7, 7, 128)        512
#  chNormalization)
#
#  re_lu_19 (ReLU)             (None, 7, 7, 128)         0
#
#  conv2d_17 (Conv2D)          (None, 7, 7, 128)         16512
#
#  batch_normalization_20 (Bat  (None, 7, 7, 128)        512
#  chNormalization)
#
#  re_lu_20 (ReLU)             (None, 7, 7, 128)         0
#
#  depthwise_conv2d_3 (Depthwi  (None, 4, 4, 128)        1280
#  seConv2D)
#
#  batch_normalization_21 (Bat  (None, 4, 4, 128)        512
#  chNormalization)
#
#  re_lu_21 (ReLU)             (None, 4, 4, 128)         0
#
#  conv2d_18 (Conv2D)          (None, 4, 4, 256)         33024
#
#  batch_normalization_22 (Bat  (None, 4, 4, 256)        1024
#  chNormalization)
#
#  re_lu_22 (ReLU)             (None, 4, 4, 256)         0
#
#  depthwise_conv2d_4 (Depthwi  (None, 4, 4, 256)        2560
#  seConv2D)
#
#  batch_normalization_23 (Bat  (None, 4, 4, 256)        1024
#  chNormalization)
#
#  re_lu_23 (ReLU)             (None, 4, 4, 256)         0
#
#  conv2d_19 (Conv2D)          (None, 4, 4, 256)         65792
#
#  batch_normalization_24 (Bat  (None, 4, 4, 256)        1024
#  chNormalization)
#
#  re_lu_24 (ReLU)             (None, 4, 4, 256)         0
#
#  depthwise_conv2d_5 (Depthwi  (None, 2, 2, 256)        2560
#  seConv2D)
#
#  batch_normalization_25 (Bat  (None, 2, 2, 256)        1024
#  chNormalization)
#
#  re_lu_25 (ReLU)             (None, 2, 2, 256)         0
#
#  conv2d_20 (Conv2D)          (None, 2, 2, 512)         131584
#
#  batch_normalization_26 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  re_lu_26 (ReLU)             (None, 2, 2, 512)         0
#
#  depthwise_conv2d_6 (Depthwi  (None, 2, 2, 512)        5120
#  seConv2D)
#
#  batch_normalization_27 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  re_lu_27 (ReLU)             (None, 2, 2, 512)         0
#
#  conv2d_21 (Conv2D)          (None, 2, 2, 512)         262656
#
#  batch_normalization_28 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  re_lu_28 (ReLU)             (None, 2, 2, 512)         0
#
#  depthwise_conv2d_7 (Depthwi  (None, 2, 2, 512)        5120
#  seConv2D)
#
#  batch_normalization_29 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  re_lu_29 (ReLU)             (None, 2, 2, 512)         0
#
#  conv2d_22 (Conv2D)          (None, 2, 2, 512)         262656
#
#  batch_normalization_30 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  re_lu_30 (ReLU)             (None, 2, 2, 512)         0
#
#  depthwise_conv2d_8 (Depthwi  (None, 2, 2, 512)        5120
#  seConv2D)
#
#  batch_normalization_31 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  re_lu_31 (ReLU)             (None, 2, 2, 512)         0
#
#  conv2d_23 (Conv2D)          (None, 2, 2, 512)         262656
#
#  batch_normalization_32 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  re_lu_32 (ReLU)             (None, 2, 2, 512)         0
#
#  depthwise_conv2d_9 (Depthwi  (None, 2, 2, 512)        5120
#  seConv2D)
#
#  batch_normalization_33 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  re_lu_33 (ReLU)             (None, 2, 2, 512)         0
#
#  conv2d_24 (Conv2D)          (None, 2, 2, 512)         262656
#
#  batch_normalization_34 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  re_lu_34 (ReLU)             (None, 2, 2, 512)         0
#
#  depthwise_conv2d_10 (Depthw  (None, 2, 2, 512)        5120
#  iseConv2D)
#
#  batch_normalization_35 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  re_lu_35 (ReLU)             (None, 2, 2, 512)         0
#
#  conv2d_25 (Conv2D)          (None, 2, 2, 512)         262656
#
#  batch_normalization_36 (Bat  (None, 2, 2, 512)        2048
#  chNormalization)
#
#  re_lu_36 (ReLU)             (None, 2, 2, 512)         0
#
#  depthwise_conv2d_11 (Depthw  (None, 1, 1, 512)        5120
#  iseConv2D)
#
#  batch_normalization_37 (Bat  (None, 1, 1, 512)        2048
#  chNormalization)
#
#  re_lu_37 (ReLU)             (None, 1, 1, 512)         0
#
#  conv2d_26 (Conv2D)          (None, 1, 1, 1024)        525312
#
#  batch_normalization_38 (Bat  (None, 1, 1, 1024)       4096
#  chNormalization)
#
#  re_lu_38 (ReLU)             (None, 1, 1, 1024)        0
#
#  depthwise_conv2d_12 (Depthw  (None, 1, 1, 1024)       10240
#  iseConv2D)
#
#  batch_normalization_39 (Bat  (None, 1, 1, 1024)       4096
#  chNormalization)
#
#  re_lu_39 (ReLU)             (None, 1, 1, 1024)        0
#
#  conv2d_27 (Conv2D)          (None, 1, 1, 1024)        1049600
#
#  batch_normalization_40 (Bat  (None, 1, 1, 1024)       4096
#  chNormalization)
#
#  re_lu_40 (ReLU)             (None, 1, 1, 1024)        0
#
#  global_average_pooling2d_1   (None, 1024)             0
#  (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 3,249,482
# Trainable params: 3,227,594
# Non-trainable params: 21,888
# _________________________________________________________________
